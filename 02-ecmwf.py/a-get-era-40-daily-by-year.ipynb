# %%
import numpy as np
import datetime as dt
import calendar

dir = "01-data-raw/"

date_first_start = dt.date(1958, 1, 1)
date_first_end = dt.date(1958, 1, 31)
date_last_end = dt.date(1978, 12, 1)
date_last_end = dt.date(1978, 12, 31)

year_first = 1959
year_last = 1978

years_vec = np.arange(year_first, (year_last + 1))
months_vec = np.arange(1, 13)


for i in range(len(years_vec)):
    date_loop_start = dt.date(years_vec[i], 1, 1)
    date_loop_end = dt.date(years_vec[i], 12, 31)
    date_loop = str(date_loop_start)+'/to/'+str(date_loop_end)
    target_loop = dir+str(date_loop_start.year)+'-era40.nc'

    print(date_loop)
    print(target_loop)


print('Done successfully.')
# Out:
# 1959-01-01/to/1959-12-31
# 01-data-raw/1959-era40.nc
# 1960-01-01/to/1960-12-31
# 01-data-raw/1960-era40.nc
# 1961-01-01/to/1961-12-31
# 01-data-raw/1961-era40.nc
# 1962-01-01/to/1962-12-31
# 01-data-raw/1962-era40.nc
# 1963-01-01/to/1963-12-31
# 01-data-raw/1963-era40.nc
# 1964-01-01/to/1964-12-31
# 01-data-raw/1964-era40.nc
# 1965-01-01/to/1965-12-31
# 01-data-raw/1965-era40.nc
# 1966-01-01/to/1966-12-31
# 01-data-raw/1966-era40.nc
# 1967-01-01/to/1967-12-31
# 01-data-raw/1967-era40.nc
# 1968-01-01/to/1968-12-31
# 01-data-raw/1968-era40.nc
# 1969-01-01/to/1969-12-31
# 01-data-raw/1969-era40.nc
# 1970-01-01/to/1970-12-31
# 01-data-raw/1970-era40.nc
# 1971-01-01/to/1971-12-31
# 01-data-raw/1971-era40.nc
# 1972-01-01/to/1972-12-31
# 01-data-raw/1972-era40.nc
# 1973-01-01/to/1973-12-31
# 01-data-raw/1973-era40.nc
# 1974-01-01/to/1974-12-31
# 01-data-raw/1974-era40.nc
# 1975-01-01/to/1975-12-31
# 01-data-raw/1975-era40.nc
# 1976-01-01/to/1976-12-31
# 01-data-raw/1976-era40.nc
# 1977-01-01/to/1977-12-31
# 01-data-raw/1977-era40.nc
# 1978-01-01/to/1978-12-31
# 01-data-raw/1978-era40.nc
# Done successfully.

# %%
#!/usr/bin/env py27

from ecmwfapi import ECMWFDataServer

import numpy as np
import datetime as dt
import calendar

server = ECMWFDataServer()

dir = "01-data-raw/"

date_first_start = dt.date(1958, 1, 1)
date_first_end = dt.date(1958, 1, 31)
date_last_end = dt.date(1978, 12, 1)
date_last_end = dt.date(1978, 12, 31)

year_first = 1959
year_last = 1978

years_vec = np.arange(year_first, (year_last + 1))
months_vec = np.arange(1, 13)


for i in range(len(years_vec)):
    date_loop_start = dt.date(years_vec[i], 1, 1)
    date_loop_end = dt.date(years_vec[i], 12, 31)
    date_loop = str(date_loop_start)+'/to/'+str(date_loop_end)
    target_loop = dir+str(date_loop_start.year)+'-era40.nc'
    server.retrieve({
        'stream'    : "oper",
        'class'     : "e4",
        'dataset'   : "era40",
        'date'      : date_loop,
        'time'      : "00/06/12/18",
        'step'      : "0",
        'type'      : "an",
        'levtype'   : "pl",
        'levelist'  : "100/150/200/250/300/400/500/600/700/775/850/925/1000",
        'param'     : "129.128/130.128/131.128/132.128/135.128/155.128",
        'grid'      : "1.00/1.00",
        'target'    : target_loop,
        'format'    : "netcdf"
    })



print('Done successfully.')
# Out:
# 2016-10-28 12:17:44 ECMWF API python library 1.4.1
# 2016-10-28 12:17:44 ECMWF API at https://api.ecmwf.int/v1
# 2016-10-28 12:17:44 Welcome Sebastian Kiefer
# 2016-10-28 12:17:45 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2016-10-28 12:17:45 In case of delays, please check the MARS service activity page http://apps.ecmwf.int/mars-activity/
# 2016-10-28 12:17:45 Request submitted
# 2016-10-28 12:17:45 Request id: 581325c91fd472a457851892
# 2016-10-28 12:17:45 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_marsYoA6Vq.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20161028.102207 - Welcome to MARS with grib_api and ODB
# mars - INFO   - 20161028.102207 - MARS Client build stamp: 20160429081542
# mars - INFO   - 20161028.102207 - MARS Client version: 6.15.2
# mars - INFO   - 20161028.102207 - EMOSLIB version: 441
# mars - INFO   - 20161028.102207 - Using grib_api version 1.15.0
# mars - INFO   - 20161028.102207 - Using odb_api version: 0.11.0 (file format version: 0.5)
# mars - INFO   - 20161028.102207 - Maximum retrieval size is 20.00 G
# retrieve,class=e4,date=1959-01-01/to/1959-12-31,expect=any,expver=0001,grid=1.00/1.00,levelist=100/150/200/250/300/400/500/600/700/775/850/925/1000,levtype=pl,padding=0,param=129.128/130.128/131.128/132.128/135.128/155.128,step=0,stream=oper,time=00/06/12/18,type=anmars - INFO   - 20161028.102207 - Automatic split by date is on
# mars - INFO   - 20161028.102207 - Request has been split into 12 monthly retrievals
#
# mars - INFO   - 20161028.102207 - Processing request 1
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.102207 - Web API request id: 581325c91fd472a457851892
# mars - INFO   - 20161028.102207 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.102207 - Calling mars on 'marser', callback on 60415
# mars - INFO   - 20161028.102207 - Server task is 125 [marser]
# mars - INFO   - 20161028.102207 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102207 - Wind conversion requested by server
# mars - INFO   - 20161028.102207 - Transfering 418297880 bytes
# 2016-10-28 12:22:08 Request is active
# mars - WARN   - 20161028.102212 - INTFB: Resolution automatically set to  213
# mars - WARN   - 20161028.102212 - INTFB: Automatic resolution selectn too high:
# mars - WARN   - 20161028.102212 - INTFB: Resolution reset to input resolution:  159
# mars - INFO   - 20161028.102213 - Deriving U and V from vorticity and divergence
# mars - WARN   - 20161028.102213 - INTUVU: Resolution automatically set to  213
# mars - WARN   - 20161028.102213 - INTUVU: Automatic resolution selectn too high
# mars - WARN   - 20161028.102213 - INTUVU: Resolution reset to input resolution:  159
# mars - INFO   - 20161028.102326 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.102326 - 9672 fields have been interpolated
# mars - INFO   - 20161028.102326 - Request time:  wall: 1 min 19 sec  cpu: 1 min 13 sec
# mars - INFO   - 20161028.102326 -   Read from network: 398.92 Mbyte(s) in 5 sec  [75.01 Mbyte/sec]
# mars - INFO   - 20161028.102326 -   Visiting marser: wall: 1 min 19 sec
# mars - INFO   - 20161028.102326 -   Post-processing: wall: 54 sec cpu: 54 sec
# mars - INFO   - 20161028.102326 -   Writing to target file: 1.17 Gbyte(s) in 1 sec  [821.78 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.102326 - Processing request 2
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 19590201/19590202/19590203/19590204/19590205/19590206/19590207/19590208/19590209/19590210/19590211/19590212/19590213/19590214/19590215/19590216/19590217/19590218/19590219/19590220/19590221/19590222/19590223/19590224/19590225/19590226/19590227/19590228
#
# mars - INFO   - 20161028.102326 - Requesting any number of fields (request describes 8736)
# mars - INFO   - 20161028.102326 - Calling mars on 'marser', callback on 33119
# mars - INFO   - 20161028.102326 - Server task is 478 [marser]
# mars - INFO   - 20161028.102326 - Request cost: 7,280 fields, 360.315 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102326 - Wind conversion requested by server
# mars - INFO   - 20161028.102327 - Transfering 377817440 bytes
# mars - INFO   - 20161028.102328 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.102431 - 8736 fields retrieved from 'marser'
# mars - INFO   - 20161028.102431 - 8736 fields have been interpolated
# mars - INFO   - 20161028.102431 - Request time:  wall: 1 min 5 sec  cpu: 1 min 3 sec
# mars - INFO   - 20161028.102431 -   Read from network: 360.31 Mbyte(s) in 1 sec  [278.47 Mbyte/sec]
# mars - INFO   - 20161028.102431 -   Visiting marser: wall: 1 min 5 sec cpu: 1 min 3 sec
# mars - INFO   - 20161028.102431 -   Post-processing: wall: 47 sec cpu: 47 sec
# mars - INFO   - 20161028.102431 -   Writing to target file: 1.06 Gbyte(s) in 1 sec  [790.59 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.102431 - Processing request 3
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.102432 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.102432 - Calling mars on 'marser', callback on 45194
# mars - INFO   - 20161028.102432 - Server task is 644 [marser]
# mars - INFO   - 20161028.102432 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102432 - Wind conversion requested by server
# mars - INFO   - 20161028.102432 - Transfering 418297880 bytes
# mars - INFO   - 20161028.102435 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.102546 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.102546 - 9672 fields have been interpolated
# mars - INFO   - 20161028.102546 - Request time:  wall: 1 min 14 sec  cpu: 1 min 11 sec
# mars - INFO   - 20161028.102546 -   Read from network: 398.92 Mbyte(s) in 3 sec  [127.57 Mbyte/sec]
# mars - INFO   - 20161028.102546 -   Visiting marser: wall: 1 min 14 sec cpu: 1 min 11 sec
# mars - INFO   - 20161028.102546 -   Post-processing: wall: 52 sec cpu: 52 sec
# mars - INFO   - 20161028.102546 -   Writing to target file: 1.17 Gbyte(s) in 1 sec  [894.52 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.102546 - Processing request 4
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.102546 - Requesting any number of fields (request describes 9360)
# mars - INFO   - 20161028.102546 - Calling mars on 'marser', callback on 45192
# mars - INFO   - 20161028.102546 - Server task is 644 [marser]
# mars - INFO   - 20161028.102546 - Request cost: 7,800 fields, 386.052 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102546 - Wind conversion requested by server
# mars - INFO   - 20161028.102546 - Transfering 404804400 bytes
# mars - INFO   - 20161028.102547 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.102658 - 9360 fields retrieved from 'marser'
# mars - INFO   - 20161028.102658 - 9360 fields have been interpolated
# mars - INFO   - 20161028.102658 - Request time:  wall: 1 min 13 sec  cpu: 1 min 11 sec
# mars - INFO   - 20161028.102658 -   Read from network: 386.05 Mbyte(s) in 2 sec  [229.55 Mbyte/sec]
# mars - INFO   - 20161028.102658 -   Visiting marser: wall: 1 min 13 sec cpu: 1 min 11 sec
# mars - INFO   - 20161028.102658 -   Post-processing: wall: 52 sec cpu: 52 sec
# mars - INFO   - 20161028.102658 -   Writing to target file: 1.14 Gbyte(s) in 1 sec  [895.02 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.102658 - Processing request 5
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.102658 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.102658 - Calling mars on 'marser', callback on 47115
# mars - INFO   - 20161028.102658 - Server task is 644 [marser]
# mars - INFO   - 20161028.102658 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102658 - Wind conversion requested by server
# mars - INFO   - 20161028.102659 - Transfering 418297880 bytes
# mars - INFO   - 20161028.102659 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.102822 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.102822 - 9672 fields have been interpolated
# mars - INFO   - 20161028.102822 - Request time:  wall: 1 min 24 sec  cpu: 1 min 23 sec
# mars - INFO   - 20161028.102822 -   Read from network: 398.92 Mbyte(s) in < 1 sec [830.50 Mbyte/sec]
# mars - INFO   - 20161028.102822 -   Visiting marser: wall: 1 min 24 sec cpu: 1 min 23 sec
# mars - INFO   - 20161028.102822 -   Post-processing: wall: 1 min 2 sec cpu: 1 min 2 sec
# mars - INFO   - 20161028.102822 -   Writing to target file: 1.17 Gbyte(s) in 2 sec  [787.88 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.102822 - Processing request 6
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.102822 - Requesting any number of fields (request describes 9360)
# mars - INFO   - 20161028.102822 - Calling mars on 'marser', callback on 43024
# mars - INFO   - 20161028.102822 - Server task is 537 [marser]
# mars - INFO   - 20161028.102822 - Request cost: 7,800 fields, 386.052 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102822 - Wind conversion requested by server
# mars - INFO   - 20161028.102823 - Transfering 404804400 bytes
# mars - INFO   - 20161028.102823 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.102932 - 9360 fields retrieved from 'marser'
# mars - INFO   - 20161028.102932 - 9360 fields have been interpolated
# mars - INFO   - 20161028.102932 - Request time:  wall: 1 min 9 sec  cpu: 1 min 9 sec
# mars - INFO   - 20161028.102932 -   Read from network: 386.05 Mbyte(s) in < 1 sec [1.08 Gbyte/sec]
# mars - INFO   - 20161028.102932 -   Visiting marser: wall: 1 min 9 sec cpu: 1 min 9 sec
# mars - INFO   - 20161028.102932 -   Post-processing: wall: 51 sec cpu: 50 sec
# mars - INFO   - 20161028.102932 -   Writing to target file: 1.14 Gbyte(s) in 1 sec  [913.88 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.102932 - Processing request 7
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.102932 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.102932 - Calling mars on 'marser', callback on 42619
# mars - INFO   - 20161028.102932 - Server task is 537 [marser]
# mars - INFO   - 20161028.102932 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.102932 - Wind conversion requested by server
# mars - INFO   - 20161028.102932 - Transfering 418297880 bytes
# mars - INFO   - 20161028.102932 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.103111 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.103111 - 9672 fields have been interpolated
# mars - INFO   - 20161028.103111 - Request time:  wall: 1 min 39 sec  cpu: 1 min 38 sec
# mars - INFO   - 20161028.103111 -   Read from network: 398.92 Mbyte(s) in < 1 sec [1.05 Gbyte/sec]
# mars - INFO   - 20161028.103111 -   Visiting marser: wall: 1 min 39 sec cpu: 1 min 38 sec
# mars - INFO   - 20161028.103111 -   Post-processing: wall: 1 min 14 sec cpu: 1 min 14 sec
# mars - INFO   - 20161028.103111 -   Writing to target file: 1.17 Gbyte(s) in 2 sec  [712.76 Mbyte/sec] cpu: 2 sec
#
# mars - INFO   - 20161028.103111 - Processing request 8
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.103111 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.103111 - Calling mars on 'marser', callback on 53091
# mars - INFO   - 20161028.103111 - Server task is 537 [marser]
# mars - INFO   - 20161028.103111 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.103111 - Wind conversion requested by server
# mars - INFO   - 20161028.103111 - Transfering 418297880 bytes
# mars - INFO   - 20161028.103111 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.103246 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.103246 - 9672 fields have been interpolated
# mars - INFO   - 20161028.103246 - Request time:  wall: 1 min 35 sec  cpu: 1 min 34 sec
# mars - INFO   - 20161028.103246 -   Read from network: 398.92 Mbyte(s) in < 1 sec [1.01 Gbyte/sec]
# mars - INFO   - 20161028.103246 -   Visiting marser: wall: 1 min 35 sec cpu: 1 min 35 sec
# mars - INFO   - 20161028.103246 -   Post-processing: wall: 1 min 11 sec cpu: 1 min 11 sec
# mars - INFO   - 20161028.103246 -   Writing to target file: 1.17 Gbyte(s) in 2 sec  [681.78 Mbyte/sec] cpu: 2 sec
#
# mars - INFO   - 20161028.103246 - Processing request 9
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.103246 - Requesting any number of fields (request describes 9360)
# mars - INFO   - 20161028.103246 - Calling mars on 'marser', callback on 52978
# mars - INFO   - 20161028.103246 - Server task is 537 [marser]
# mars - INFO   - 20161028.103246 - Request cost: 7,800 fields, 386.052 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.103246 - Wind conversion requested by server
# mars - INFO   - 20161028.103246 - Transfering 404804400 bytes
# mars - INFO   - 20161028.103246 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.103411 - 9360 fields retrieved from 'marser'
# mars - INFO   - 20161028.103411 - 9360 fields have been interpolated
# mars - INFO   - 20161028.103411 - Request time:  wall: 1 min 25 sec  cpu: 1 min 24 sec
# mars - INFO   - 20161028.103411 -   Read from network: 386.05 Mbyte(s) in < 1 sec [1016.99 Mbyte/sec]
# mars - INFO   - 20161028.103411 -   Visiting marser: wall: 1 min 25 sec cpu: 1 min 24 sec
# mars - INFO   - 20161028.103411 -   Post-processing: wall: 1 min 3 sec cpu: 1 min 2 sec
# mars - INFO   - 20161028.103411 -   Writing to target file: 1.14 Gbyte(s) in 2 sec  [773.99 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.103411 - Processing request 10
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.103411 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.103411 - Calling mars on 'marser', callback on 39265
# mars - INFO   - 20161028.103411 - Server task is 879 [marser]
# mars - INFO   - 20161028.103411 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.103411 - Wind conversion requested by server
# mars - INFO   - 20161028.103411 - Transfering 418297880 bytes
# mars - INFO   - 20161028.103411 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.103523 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.103523 - 9672 fields have been interpolated
# mars - INFO   - 20161028.103523 - Request time:  wall: 1 min 13 sec  cpu: 1 min 12 sec
# mars - INFO   - 20161028.103523 -   Read from network: 398.92 Mbyte(s) in < 1 sec [1.15 Gbyte/sec]
# mars - INFO   - 20161028.103523 -   Visiting marser: wall: 1 min 13 sec cpu: 1 min 13 sec
# mars - INFO   - 20161028.103523 -   Post-processing: wall: 54 sec cpu: 53 sec
# mars - INFO   - 20161028.103523 -   Writing to target file: 1.17 Gbyte(s) in 1 sec  [959.00 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.103523 - Processing request 11
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.103524 - Requesting any number of fields (request describes 9360)
# mars - INFO   - 20161028.103524 - Calling mars on 'marser', callback on 33537
# mars - INFO   - 20161028.103524 - Server task is 879 [marser]
# mars - INFO   - 20161028.103524 - Request cost: 7,800 fields, 386.052 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.103524 - Wind conversion requested by server
# mars - INFO   - 20161028.103524 - Transfering 404804400 bytes
# mars - INFO   - 20161028.103525 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.103636 - 9360 fields retrieved from 'marser'
# mars - INFO   - 20161028.103636 - 9360 fields have been interpolated
# mars - INFO   - 20161028.103636 - Request time:  wall: 1 min 12 sec  cpu: 1 min 10 sec
# mars - INFO   - 20161028.103636 -   Read from network: 386.05 Mbyte(s) in 2 sec  [247.54 Mbyte/sec]
# mars - INFO   - 20161028.103636 -   Visiting marser: wall: 1 min 12 sec cpu: 1 min 11 sec
# mars - INFO   - 20161028.103636 -   Post-processing: wall: 52 sec cpu: 52 sec
# mars - INFO   - 20161028.103636 -   Writing to target file: 1.14 Gbyte(s) in 2 sec  [771.19 Mbyte/sec] cpu: 1 sec
#
# mars - INFO   - 20161028.103636 - Processing request 12
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.103636 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.103636 - Calling mars on 'marser', callback on 52105
# mars - INFO   - 20161028.103636 - Server task is 879 [marser]
# mars - INFO   - 20161028.103636 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.103636 - Wind conversion requested by server
# mars - INFO   - 20161028.103636 - Transfering 418297880 bytes
# mars - INFO   - 20161028.103639 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20161028.103754 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.103754 - 9672 fields have been interpolated
# mars - INFO   - 20161028.103754 - Request time:  wall: 1 min 18 sec  cpu: 1 min 15 sec
# mars - INFO   - 20161028.103754 -   Read from network: 398.92 Mbyte(s) in 3 sec  [141.52 Mbyte/sec]
# mars - INFO   - 20161028.103754 -   Visiting marser: wall: 1 min 18 sec cpu: 1 min 15 sec
# mars - INFO   - 20161028.103754 -   Post-processing: wall: 55 sec cpu: 55 sec
# mars - INFO   - 20161028.103754 -   Writing to target file: 1.17 Gbyte(s) in 1 sec  [902.61 Mbyte/sec] cpu: 1 sec
# mars - INFO   - 20161028.103754 - No errors reported
# Process '['nice', 'mars', '/tmp/tmp-_marsYoA6Vq.req']' finished
# Calling '['nice', 'grib_to_netcdf', '/data/data01/scratch/_mars-atls19-95e2cf679cd58ee9b4db4dd119a05a8d-AL6ZQm.grib', '-o', '/data/data01/scratch/_grib2netcdf-atls19-95e2cf679cd58ee9b4db4dd119a05a8d-iAoRdJ.nc', '-utime']'
# 2016-10-28 12:48:36 Request is complete
# 2016-10-28 12:48:36 Transfering 13.8216 Gbytes into 01-data-raw/1959-era40.nc
# 2016-10-28 12:48:36 From http://stream.ecmwf.int/data/atls19/data/data01/scratch/_grib2netcdf-atls19-95e2cf679cd58ee9b4db4dd119a05a8d-iAoRdJ.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7a1e61f1d25e> in <module>()
#      41         'grid'      : "1.00/1.00",
#      42         'target'    : target_loop,
# ---> 43         'format'    : "netcdf"
#      44     })
#      45
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/site-packages/ecmwfapi/api.pyc in retrieve(self, req)
#     488         dataset = req.get("dataset")
#     489         c = APIRequest(self.url, "datasets/%s" % (dataset,), self.email, self.key, self.trace, verbose=self.verbose)
# --> 490         c.execute(req, target)
#     491
#     492 ###############################################################################
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/site-packages/ecmwfapi/api.pyc in execute(self, request, target)
#     448             tries = 0
#     449             while size != result["size"] and tries < 10:
# --> 450                 size = self._transfer(result["href"], target, result["size"])
#     451                 if size != result["size"] and tries < 10:
#     452                     tries += 1
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/site-packages/ecmwfapi/api.pyc in wrapped(self, *args, **kwargs)
#     134         while tries > 0:
#     135             try:
# --> 136                 return func(self, *args, **kwargs)
#     137             except HTTPError as e:
#     138                 if self.verbose:
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/site-packages/ecmwfapi/api.pyc in _transfer(self, url, path, size)
#     402         block = 1024 * 1024
#     403         while True:
# --> 404             chunk = http.read(block)
#     405             if not chunk:
#     406                 break
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/socket.pyc in read(self, size)
#     382                 # fragmentation issues on many platforms.
#     383                 try:
# --> 384                     data = self._sock.recv(left)
#     385                 except error, e:
#     386                     if e.args[0] == EINTR:
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/httplib.pyc in read(self, amt)
#     610         # connection, and the user is reading more bytes than will be provided
#     611         # (for example, reading in 1k chunks)
# --> 612         s = self.fp.read(amt)
#     613         if not s and amt:
#     614             # Ideally, we would raise IncompleteRead if the content-length
#
# /home/jdoe/anaconda3/envs/py27/lib/python2.7/socket.pyc in read(self, size)
#     382                 # fragmentation issues on many platforms.
#     383                 try:
# --> 384                     data = self._sock.recv(left)
#     385                 except error, e:
#     386                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
