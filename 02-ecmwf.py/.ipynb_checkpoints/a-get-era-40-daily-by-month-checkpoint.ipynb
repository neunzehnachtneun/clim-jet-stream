# %%
import numpy as np
import datetime as dt
import calendar

dir = "01-data-raw/"

date_first_start = dt.date(1958, 1, 1)
date_first_end = dt.date(1958, 1, 31)
date_last_end = dt.date(1978, 12, 1)
date_last_end = dt.date(1978, 12, 31)

year_first = 1958
year_last = 1978

years_vec = np.arange(year_first, (year_last + 1))
months_vec = np.arange(1, 13)


for i in range(len(years_vec)):
    for ii in range(len(months_vec)):
        date_loop_start = dt.date(years_vec[i], months_vec[ii], 1)
        month_len = calendar.monthrange(years_vec[i], months_vec[ii])[1]
        date_loop_end = dt.date(years_vec[i], months_vec[ii], month_len)
        date_loop = str(date_loop_start)+'/to/'+str(date_loop_end)
        target_loop = dir+str(date_loop_start.year)+'-'+str(date_loop_start.month)+'-era40.nc'
        
        
        print(date_loop)
        print(target_loop)

print('Done successfully.')
# Out:
# 1958-01-01/to/1958-01-31
# 01-data-raw/1958-1-era40.nc
# 1958-02-01/to/1958-02-28
# 01-data-raw/1958-2-era40.nc
# 1958-03-01/to/1958-03-31
# 01-data-raw/1958-3-era40.nc
# 1958-04-01/to/1958-04-30
# 01-data-raw/1958-4-era40.nc
# 1958-05-01/to/1958-05-31
# 01-data-raw/1958-5-era40.nc
# 1958-06-01/to/1958-06-30
# 01-data-raw/1958-6-era40.nc
# 1958-07-01/to/1958-07-31
# 01-data-raw/1958-7-era40.nc
# 1958-08-01/to/1958-08-31
# 01-data-raw/1958-8-era40.nc
# 1958-09-01/to/1958-09-30
# 01-data-raw/1958-9-era40.nc
# 1958-10-01/to/1958-10-31
# 01-data-raw/1958-10-era40.nc
# 1958-11-01/to/1958-11-30
# 01-data-raw/1958-11-era40.nc
# 1958-12-01/to/1958-12-31
# 01-data-raw/1958-12-era40.nc
# 1959-01-01/to/1959-01-31
# 01-data-raw/1959-1-era40.nc
# 1959-02-01/to/1959-02-28
# 01-data-raw/1959-2-era40.nc
# 1959-03-01/to/1959-03-31
# 01-data-raw/1959-3-era40.nc
# 1959-04-01/to/1959-04-30
# 01-data-raw/1959-4-era40.nc
# 1959-05-01/to/1959-05-31
# 01-data-raw/1959-5-era40.nc
# 1959-06-01/to/1959-06-30
# 01-data-raw/1959-6-era40.nc
# 1959-07-01/to/1959-07-31
# 01-data-raw/1959-7-era40.nc
# 1959-08-01/to/1959-08-31
# 01-data-raw/1959-8-era40.nc
# 1959-09-01/to/1959-09-30
# 01-data-raw/1959-9-era40.nc
# 1959-10-01/to/1959-10-31
# 01-data-raw/1959-10-era40.nc
# 1959-11-01/to/1959-11-30
# 01-data-raw/1959-11-era40.nc
# 1959-12-01/to/1959-12-31
# 01-data-raw/1959-12-era40.nc
# 1960-01-01/to/1960-01-31
# 01-data-raw/1960-1-era40.nc
# 1960-02-01/to/1960-02-29
# 01-data-raw/1960-2-era40.nc
# 1960-03-01/to/1960-03-31
# 01-data-raw/1960-3-era40.nc
# 1960-04-01/to/1960-04-30
# 01-data-raw/1960-4-era40.nc
# 1960-05-01/to/1960-05-31
# 01-data-raw/1960-5-era40.nc
# 1960-06-01/to/1960-06-30
# 01-data-raw/1960-6-era40.nc
# 1960-07-01/to/1960-07-31
# 01-data-raw/1960-7-era40.nc
# 1960-08-01/to/1960-08-31
# 01-data-raw/1960-8-era40.nc
# 1960-09-01/to/1960-09-30
# 01-data-raw/1960-9-era40.nc
# 1960-10-01/to/1960-10-31
# 01-data-raw/1960-10-era40.nc
# 1960-11-01/to/1960-11-30
# 01-data-raw/1960-11-era40.nc
# 1960-12-01/to/1960-12-31
# 01-data-raw/1960-12-era40.nc
# 1961-01-01/to/1961-01-31
# 01-data-raw/1961-1-era40.nc
# 1961-02-01/to/1961-02-28
# 01-data-raw/1961-2-era40.nc
# 1961-03-01/to/1961-03-31
# 01-data-raw/1961-3-era40.nc
# 1961-04-01/to/1961-04-30
# 01-data-raw/1961-4-era40.nc
# 1961-05-01/to/1961-05-31
# 01-data-raw/1961-5-era40.nc
# 1961-06-01/to/1961-06-30
# 01-data-raw/1961-6-era40.nc
# 1961-07-01/to/1961-07-31
# 01-data-raw/1961-7-era40.nc
# 1961-08-01/to/1961-08-31
# 01-data-raw/1961-8-era40.nc
# 1961-09-01/to/1961-09-30
# 01-data-raw/1961-9-era40.nc
# 1961-10-01/to/1961-10-31
# 01-data-raw/1961-10-era40.nc
# 1961-11-01/to/1961-11-30
# 01-data-raw/1961-11-era40.nc
# 1961-12-01/to/1961-12-31
# 01-data-raw/1961-12-era40.nc
# 1962-01-01/to/1962-01-31
# 01-data-raw/1962-1-era40.nc
# 1962-02-01/to/1962-02-28
# 01-data-raw/1962-2-era40.nc
# 1962-03-01/to/1962-03-31
# 01-data-raw/1962-3-era40.nc
# 1962-04-01/to/1962-04-30
# 01-data-raw/1962-4-era40.nc
# 1962-05-01/to/1962-05-31
# 01-data-raw/1962-5-era40.nc
# 1962-06-01/to/1962-06-30
# 01-data-raw/1962-6-era40.nc
# 1962-07-01/to/1962-07-31
# 01-data-raw/1962-7-era40.nc
# 1962-08-01/to/1962-08-31
# 01-data-raw/1962-8-era40.nc
# 1962-09-01/to/1962-09-30
# 01-data-raw/1962-9-era40.nc
# 1962-10-01/to/1962-10-31
# 01-data-raw/1962-10-era40.nc
# 1962-11-01/to/1962-11-30
# 01-data-raw/1962-11-era40.nc
# 1962-12-01/to/1962-12-31
# 01-data-raw/1962-12-era40.nc
# 1963-01-01/to/1963-01-31
# 01-data-raw/1963-1-era40.nc
# 1963-02-01/to/1963-02-28
# 01-data-raw/1963-2-era40.nc
# 1963-03-01/to/1963-03-31
# 01-data-raw/1963-3-era40.nc
# 1963-04-01/to/1963-04-30
# 01-data-raw/1963-4-era40.nc
# 1963-05-01/to/1963-05-31
# 01-data-raw/1963-5-era40.nc
# 1963-06-01/to/1963-06-30
# 01-data-raw/1963-6-era40.nc
# 1963-07-01/to/1963-07-31
# 01-data-raw/1963-7-era40.nc
# 1963-08-01/to/1963-08-31
# 01-data-raw/1963-8-era40.nc
# 1963-09-01/to/1963-09-30
# 01-data-raw/1963-9-era40.nc
# 1963-10-01/to/1963-10-31
# 01-data-raw/1963-10-era40.nc
# 1963-11-01/to/1963-11-30
# 01-data-raw/1963-11-era40.nc
# 1963-12-01/to/1963-12-31
# 01-data-raw/1963-12-era40.nc
# 1964-01-01/to/1964-01-31
# 01-data-raw/1964-1-era40.nc
# 1964-02-01/to/1964-02-29
# 01-data-raw/1964-2-era40.nc
# 1964-03-01/to/1964-03-31
# 01-data-raw/1964-3-era40.nc
# 1964-04-01/to/1964-04-30
# 01-data-raw/1964-4-era40.nc
# 1964-05-01/to/1964-05-31
# 01-data-raw/1964-5-era40.nc
# 1964-06-01/to/1964-06-30
# 01-data-raw/1964-6-era40.nc
# 1964-07-01/to/1964-07-31
# 01-data-raw/1964-7-era40.nc
# 1964-08-01/to/1964-08-31
# 01-data-raw/1964-8-era40.nc
# 1964-09-01/to/1964-09-30
# 01-data-raw/1964-9-era40.nc
# 1964-10-01/to/1964-10-31
# 01-data-raw/1964-10-era40.nc
# 1964-11-01/to/1964-11-30
# 01-data-raw/1964-11-era40.nc
# 1964-12-01/to/1964-12-31
# 01-data-raw/1964-12-era40.nc
# 1965-01-01/to/1965-01-31
# 01-data-raw/1965-1-era40.nc
# 1965-02-01/to/1965-02-28
# 01-data-raw/1965-2-era40.nc
# 1965-03-01/to/1965-03-31
# 01-data-raw/1965-3-era40.nc
# 1965-04-01/to/1965-04-30
# 01-data-raw/1965-4-era40.nc
# 1965-05-01/to/1965-05-31
# 01-data-raw/1965-5-era40.nc
# 1965-06-01/to/1965-06-30
# 01-data-raw/1965-6-era40.nc
# 1965-07-01/to/1965-07-31
# 01-data-raw/1965-7-era40.nc
# 1965-08-01/to/1965-08-31
# 01-data-raw/1965-8-era40.nc
# 1965-09-01/to/1965-09-30
# 01-data-raw/1965-9-era40.nc
# 1965-10-01/to/1965-10-31
# 01-data-raw/1965-10-era40.nc
# 1965-11-01/to/1965-11-30
# 01-data-raw/1965-11-era40.nc
# 1965-12-01/to/1965-12-31
# 01-data-raw/1965-12-era40.nc
# 1966-01-01/to/1966-01-31
# 01-data-raw/1966-1-era40.nc
# 1966-02-01/to/1966-02-28
# 01-data-raw/1966-2-era40.nc
# 1966-03-01/to/1966-03-31
# 01-data-raw/1966-3-era40.nc
# 1966-04-01/to/1966-04-30
# 01-data-raw/1966-4-era40.nc
# 1966-05-01/to/1966-05-31
# 01-data-raw/1966-5-era40.nc
# 1966-06-01/to/1966-06-30
# 01-data-raw/1966-6-era40.nc
# 1966-07-01/to/1966-07-31
# 01-data-raw/1966-7-era40.nc
# 1966-08-01/to/1966-08-31
# 01-data-raw/1966-8-era40.nc
# 1966-09-01/to/1966-09-30
# 01-data-raw/1966-9-era40.nc
# 1966-10-01/to/1966-10-31
# 01-data-raw/1966-10-era40.nc
# 1966-11-01/to/1966-11-30
# 01-data-raw/1966-11-era40.nc
# 1966-12-01/to/1966-12-31
# 01-data-raw/1966-12-era40.nc
# 1967-01-01/to/1967-01-31
# 01-data-raw/1967-1-era40.nc
# 1967-02-01/to/1967-02-28
# 01-data-raw/1967-2-era40.nc
# 1967-03-01/to/1967-03-31
# 01-data-raw/1967-3-era40.nc
# 1967-04-01/to/1967-04-30
# 01-data-raw/1967-4-era40.nc
# 1967-05-01/to/1967-05-31
# 1974-04-01/to/1974-04-30
# 01-data-raw/1974-4-era40.nc
# 1974-05-01/to/1974-05-31
# 01-data-raw/1974-5-era40.nc
# 1974-06-01/to/1974-06-30
# 01-data-raw/1974-6-era40.nc
# 1974-07-01/to/1974-07-31
# 01-data-raw/1974-7-era40.nc
# 1974-08-01/to/1974-08-31
# 01-data-raw/1974-8-era40.nc
# 1974-09-01/to/1974-09-30
# 01-data-raw/1974-9-era40.nc
# 1974-10-01/to/1974-10-31
# 01-data-raw/1974-10-era40.nc
# 1974-11-01/to/1974-11-30
# 01-data-raw/1974-11-era40.nc
# 1974-12-01/to/1974-12-31
# 01-data-raw/1974-12-era40.nc
# 1975-01-01/to/1975-01-31
# 01-data-raw/1975-1-era40.nc
# 1975-02-01/to/1975-02-28
# 01-data-raw/1975-2-era40.nc
# 1975-03-01/to/1975-03-31
# 01-data-raw/1975-3-era40.nc
# 1975-04-01/to/1975-04-30
# 01-data-raw/1975-4-era40.nc
# 1975-05-01/to/1975-05-31
# 01-data-raw/1975-5-era40.nc
# 1975-06-01/to/1975-06-30
# 01-data-raw/1975-6-era40.nc
# 1975-07-01/to/1975-07-31
# 01-data-raw/1975-7-era40.nc
# 1975-08-01/to/1975-08-31
# 01-data-raw/1975-8-era40.nc
# 1975-09-01/to/1975-09-30
# 01-data-raw/1975-9-era40.nc
# 1975-10-01/to/1975-10-31
# 01-data-raw/1975-10-era40.nc
# 1975-11-01/to/1975-11-30
# 01-data-raw/1975-11-era40.nc
# 1975-12-01/to/1975-12-31
# 01-data-raw/1975-12-era40.nc
# 1976-01-01/to/1976-01-31
# 01-data-raw/1976-1-era40.nc
# 1976-02-01/to/1976-02-29
# 01-data-raw/1976-2-era40.nc
# 1976-03-01/to/1976-03-31
# 01-data-raw/1976-3-era40.nc
# 1976-04-01/to/1976-04-30
# 01-data-raw/1976-4-era40.nc
# 1976-05-01/to/1976-05-31
# 01-data-raw/1976-5-era40.nc
# 1976-06-01/to/1976-06-30
# 01-data-raw/1976-6-era40.nc
# 1976-07-01/to/1976-07-31
# 01-data-raw/1976-7-era40.nc
# 1976-08-01/to/1976-08-31
# 01-data-raw/1976-8-era40.nc
# 1976-09-01/to/1976-09-30
# 01-data-raw/1976-9-era40.nc
# 1976-10-01/to/1976-10-31
# 01-data-raw/1976-10-era40.nc
# 1976-11-01/to/1976-11-30
# 01-data-raw/1976-11-era40.nc
# 1976-12-01/to/1976-12-31
# 01-data-raw/1976-12-era40.nc
# 1977-01-01/to/1977-01-31
# 01-data-raw/1977-1-era40.nc
# 1977-02-01/to/1977-02-28
# 01-data-raw/1977-2-era40.nc
# 1977-03-01/to/1977-03-31
# 01-data-raw/1977-3-era40.nc
# 1977-04-01/to/1977-04-30
# 01-data-raw/1977-4-era40.nc
# 1977-05-01/to/1977-05-31
# 01-data-raw/1977-5-era40.nc
# 1977-06-01/to/1977-06-30
# 01-data-raw/1977-6-era40.nc
# 1977-07-01/to/1977-07-31
# 01-data-raw/1977-7-era40.nc
# 1977-08-01/to/1977-08-31
# 01-data-raw/1977-8-era40.nc
# 1977-09-01/to/1977-09-30
# 01-data-raw/1977-9-era40.nc
# 1977-10-01/to/1977-10-31
# 01-data-raw/1977-10-era40.nc
# 1977-11-01/to/1977-11-30
# 01-data-raw/1977-11-era40.nc
# 1977-12-01/to/1977-12-31
# 01-data-raw/1977-12-era40.nc
# 1978-01-01/to/1978-01-31
# 01-data-raw/1978-1-era40.nc
# 1978-02-01/to/1978-02-28
# 01-data-raw/1978-2-era40.nc
# 1978-03-01/to/1978-03-31
# 01-data-raw/1978-3-era40.nc
# 1978-04-01/to/1978-04-30
# 01-data-raw/1978-4-era40.nc
# 1978-05-01/to/1978-05-31
# 01-data-raw/1978-5-era40.nc
# 1978-06-01/to/1978-06-30
# 01-data-raw/1978-6-era40.nc
# 1978-07-01/to/1978-07-31
# 01-data-raw/1978-7-era40.nc
# 1978-08-01/to/1978-08-31
# 01-data-raw/1978-8-era40.nc
# 1978-09-01/to/1978-09-30
# 01-data-raw/1978-9-era40.nc
# 1978-10-01/to/1978-10-31
# 01-data-raw/1978-10-era40.nc
# 1978-11-01/to/1978-11-30
# 01-data-raw/1978-11-era40.nc
# 1978-12-01/to/1978-12-31
# 01-data-raw/1978-12-era40.nc
# Done successfully.

# %%
#!/usr/bin/env py27

from ecmwfapi import ECMWFDataServer

import numpy as np
import datetime as dt
import calendar

server = ECMWFDataServer()

dir = "01-data-raw/"

date_first_start = dt.date(1958, 1, 1)
date_first_end = dt.date(1958, 1, 31)
date_last_end = dt.date(1978, 12, 1)
date_last_end = dt.date(1978, 12, 31)

year_first = 1958
year_last = 1978

years_vec = np.arange(year_first, (year_last + 1))
months_vec = np.arange(1, 13)


for i in range(1):
    for ii in range(12):
        date_loop_start = dt.date(years_vec[i], months_vec[ii], 1)
        month_len = calendar.monthrange(years_vec[i], months_vec[ii])[1]
        date_loop_end = dt.date(years_vec[i], months_vec[ii], month_len)
        date_loop = str(date_loop_start)+'/to/'+str(date_loop_end)
        target_loop = dir+str(date_loop_start.year)+'-'+str(date_loop_start.month)+'-era40.nc'
        
        server.retrieve({
            'stream'    : "oper",
            'class'     : "e4",
            'dataset'   : "era40",
            'date'      : date_loop,
            'time'      : "00/06/12/18",
            'step'      : "0",
            'type'      : "an",
            'levtype'   : "pl",
            'levelist'  : "100/150/200/250/300/400/500/600/700/775/850/925/1000",
            'param'     : "129.128/130.128/131.128/132.128/135.128/155.128",
            'grid'      : "1.00/1.00",
            'target'    : target_loop,
            'format'    : "netcdf"
        })
        
#        print(date_loop)
#        print(target_loop)

print('Done successfully.')
# Out:
# 2016-10-28 13:45:18 ECMWF API python library 1.4.1
# 2016-10-28 13:45:18 ECMWF API at https://api.ecmwf.int/v1
# 2016-10-28 13:45:18 Welcome Sebastian Kiefer
# 2016-10-28 13:45:18 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2016-10-28 13:45:18 In case of delays, please check the MARS service activity page http://apps.ecmwf.int/mars-activity/
# 2016-10-28 13:45:18 Request submitted
# 2016-10-28 13:45:18 Request id: 58133a4e61685078ed103307
# 2016-10-28 13:45:18 Request is queued
