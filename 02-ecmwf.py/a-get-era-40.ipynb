# %%
#!/usr/bin/env py27
from ecmwfapi import ECMWFDataServer

server = ECMWFDataServer()

server.retrieve({
    'stream'    : "oper",
    'class'     : "e4",
    'dataset'   : "era40",
    'date'      : "2002-08-01", #/to/2002-08-31",
    'time'      : "00/06/12/18",
    'step'      : "0",
    'type'      : "an",
    'levtype'   : "pl",
    'levelist'  : "100/200/300/500/850/1000",
    'param'     : "129.128/130.128/131.128/132.128/135.128/155.128",
    'grid'      : "1.00/1.00",
    'target'    : "01-data-raw/test-era40.nc",
    'format'    : "netcdf"
    })
# Out:
# 2016-10-26 18:22:28 ECMWF API python library 1.4.1
# 2016-10-26 18:22:28 ECMWF API at https://api.ecmwf.int/v1
# 2016-10-26 18:22:28 Welcome Sebastian Kiefer
# 2016-10-26 18:22:28 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2016-10-26 18:22:28 In case of delays, please check the MARS service activity page http://apps.ecmwf.int/mars-activity/
# 2016-10-26 18:22:28 Request submitted
# 2016-10-26 18:22:28 Request id: 5810d844d64e609ab635f8ca
# 2016-10-26 18:22:28 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_marsH_mh95.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20161026.162230 - Welcome to MARS with grib_api and ODB
# ...
