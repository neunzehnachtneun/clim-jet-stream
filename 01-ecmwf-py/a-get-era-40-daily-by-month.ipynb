# %%
import numpy as np
import datetime as dt
import calendar

dir = "01-data-raw/"

date_first_start = dt.date(1958, 1, 1)
date_first_end = dt.date(1958, 1, 31)
date_last_end = dt.date(1978, 12, 1)
date_last_end = dt.date(1978, 12, 31)

year_first = 1958
year_last = 1978

years_vec = np.arange(year_first, (year_last + 1))
months_vec = np.arange(1, 13)


for i in range(len(years_vec)):
    for ii in range(len(months_vec)):
        date_loop_start = dt.date(years_vec[i], months_vec[ii], 1)
        month_len = calendar.monthrange(years_vec[i], months_vec[ii])[1]
        date_loop_end = dt.date(years_vec[i], months_vec[ii], month_len)
        date_loop = str(date_loop_start)+'/to/'+str(date_loop_end)
        target_loop = dir+str(date_loop_start.year)+'-'+str(date_loop_start.month)+'-era40.nc'
        
        
print(date_loop)
print(target_loop)
print('Done successfully.')

# %%
#!/usr/bin/env py27

from ecmwfapi import ECMWFDataServer

import numpy as np
import datetime as dt
import calendar

server = ECMWFDataServer()

dir = "/automount/agh/Projects/skiefer/era-40-raw/"

date_first_start = dt.date(1958, 1, 1)
date_first_end = dt.date(1958, 1, 31)
date_last_end = dt.date(1978, 12, 1)
date_last_end = dt.date(1978, 12, 31)

year_first = 1958
year_last = 1978

years_vec = np.arange(year_first, (year_last + 1))
months_vec = np.arange(1, 13)


for i in range(1):
    for ii in range(12):
        date_loop_start = dt.date(years_vec[i], months_vec[ii], 1)
        month_len = calendar.monthrange(years_vec[i], months_vec[ii])[1]
        date_loop_end = dt.date(years_vec[i], months_vec[ii], month_len)
        date_loop = str(date_loop_start)+'/to/'+str(date_loop_end)
        target_loop = dir+str(date_loop_start.year)+'-'+str(date_loop_start.month)+'-era40.nc'
        
        server.retrieve({
            'stream'    : "oper",
            'class'     : "e4",
            'dataset'   : "era40",
            'date'      : date_loop,
            'time'      : "00/06/12/18",
            'step'      : "0",
            'type'      : "an",
            'levtype'   : "pl",
            'levelist'  : "100/150/200/250/300/400/500/600/700/775/850/925/1000",
            'param'     : "129.128/130.128/131.128/132.128/135.128/155.128",
            'grid'      : "1.00/1.00",
            'target'    : target_loop,
            'format'    : "netcdf"
        })
        
#        print(date_loop)
#        print(target_loop)

print('Done successfully.')
# Out:
# 2016-10-28 14:57:38 ECMWF API python library 1.4.1
# 2016-10-28 14:57:38 ECMWF API at https://api.ecmwf.int/v1
# 2016-10-28 14:57:38 Welcome Sebastian Kiefer
# 2016-10-28 14:57:43 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2016-10-28 14:57:43 In case of delays, please check the MARS service activity page http://apps.ecmwf.int/mars-activity/
# 2016-10-28 14:57:44 Request submitted
# 2016-10-28 14:57:44 Request id: 58134b47f7414d50c7cb6cec
# 2016-10-28 14:57:44 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_mars6B21LR.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20161028.125744 - Welcome to MARS with grib_api and ODB
# mars - INFO   - 20161028.125744 - MARS Client build stamp: 20160429081542
# mars - INFO   - 20161028.125744 - MARS Client version: 6.15.2
# mars - INFO   - 20161028.125744 - EMOSLIB version: 441
# mars - INFO   - 20161028.125744 - Using grib_api version 1.15.0
# mars - INFO   - 20161028.125744 - Using odb_api version: 0.11.0 (file format version: 0.5)
# mars - INFO   - 20161028.125744 - Maximum retrieval size is 20.00 G
# retrieve,class=e4,date=1958-01-01/to/1958-01-31,expect=any,expver=0001,grid=1.00/1.00,levelist=100/150/200/250/300/400/500/600/700/775/850/925/1000,levtype=pl,padding=0,param=129.128/130.128/131.128/132.128/135.128/155.128,step=0,stream=oper,time=00/06/12/18,type=anmars - INFO   - 20161028.125744 - Automatic split by date is on
#
# mars - INFO   - 20161028.125744 - Processing request 1
#
# RETRIEVE,
#     CLASS      = E4,
#     TYPE       = AN,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 100/150/200/250/300/400/500/600/700/775/850/925/1000,
#     PARAM      = 129.128/130.128/131.128/132.128/135.128/155.128,
#     TIME       = 0000/0600/1200/1800,
#     STEP       = 0,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     GRID       = 1.00/1.00,
#     PADDING    = 0,
#     EXPECT     = ANY,
#     DATE       = 
#
# mars - INFO   - 20161028.125744 - Web API request id: 58134b47f7414d50c7cb6cec
# mars - INFO   - 20161028.125745 - Requesting any number of fields (request describes 9672)
# mars - INFO   - 20161028.125745 - Calling mars on 'marser', callback on 38112
# mars - INFO   - 20161028.125745 - Server task is 824 [marser]
# mars - INFO   - 20161028.125745 - Request cost: 8,060 fields, 398.92 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20161028.125745 - Wind conversion requested by server
# 2016-10-28 14:57:45 Request is active
# mars - INFO   - 20161028.125745 - Transfering 418297880 bytes
# mars - WARN   - 20161028.125747 - INTFB: Resolution automatically set to  213
# mars - WARN   - 20161028.125747 - INTFB: Automatic resolution selectn too high:
# mars - WARN   - 20161028.125747 - INTFB: Resolution reset to input resolution:  159
# mars - INFO   - 20161028.125747 - Deriving U and V from vorticity and divergence
# mars - WARN   - 20161028.125747 - INTUVU: Resolution automatically set to  213
# mars - WARN   - 20161028.125747 - INTUVU: Automatic resolution selectn too high
# mars - WARN   - 20161028.125747 - INTUVU: Resolution reset to input resolution:  159
# mars - INFO   - 20161028.125902 - 9672 fields retrieved from 'marser'
# mars - INFO   - 20161028.125902 - 9672 fields have been interpolated
# mars - INFO   - 20161028.125902 - Request time:  wall: 1 min 18 sec  cpu: 1 min 15 sec
# mars - INFO   - 20161028.125902 -   Read from network: 398.92 Mbyte(s) in 2 sec  [184.24 Mbyte/sec]
# mars - INFO   - 20161028.125902 -   Visiting marser: wall: 1 min 18 sec
# mars - INFO   - 20161028.125902 -   Post-processing: wall: 55 sec cpu: 54 sec
# mars - INFO   - 20161028.125902 -   Writing to target file: 1.17 Gbyte(s) in 2 sec  [572.91 Mbyte/sec] cpu: 2 sec
# mars - INFO   - 20161028.125902 - No errors reported
# Process '['nice', 'mars', '/tmp/tmp-_mars6B21LR.req']' finished
# Calling '['nice', 'grib_to_netcdf', '/data/data01/scratch/_mars-atls09-95e2cf679cd58ee9b4db4dd119a05a8d-Bigbc5.grib', '-o', '/data/data01/scratch/_grib2netcdf-atls02-95e2cf679cd58ee9b4db4dd119a05a8d-oW2YWD.nc', '-utime']'
# grib_to_netcdf: Version 1.16.0
# grib_to_netcdf: Processing input file '/data/data01/scratch/_mars-atls09-95e2cf679cd58ee9b4db4dd119a05a8d-Bigbc5.grib'.
# grib_to_netcdf: Found 9672 GRIB fields in 1 file.
# grib_to_netcdf: Ignoring key(s): method, type, stream, refdate, hdate
# grib_to_netcdf: Creating netCDF file '/data/data01/scratch/_grib2netcdf-atls02-95e2cf679cd58ee9b4db4dd119a05a8d-oW2YWD.nc'
# grib_to_netcdf: NetCDF library version: 4.3.0 of Aug 22 2016 13:47:27 $
# grib_to_netcdf: Creating large (64 bit) file format.
# grib_to_netcdf: Defining variable 'z'.
# grib_to_netcdf: Defining variable 't'.
# grib_to_netcdf: Defining variable 'w'.
# grib_to_netcdf: Defining variable 'd'.
# grib_to_netcdf: Defining variable 'u'.
# grib_to_netcdf: Defining variable 'v'.
# grib_to_netcdf: Done.
# Process '['nice', 'grib_to_netcdf', '/data/data01/scratch/_mars-atls09-95e2cf679cd58ee9b4db4dd119a05a8d-Bigbc5.grib', '-o', '/data/data01/scratch/_grib2netcdf-atls02-95e2cf679cd58ee9b4db4dd119a05a8d-oW2YWD.nc', '-utime']' finished
# 2016-10-28 15:00:09 Request is complete
# 2016-10-28 15:00:09 Transfering 1.1739 Gbytes into /automount/agh/Projects/skiefer/era-40-raw/1958-1-era40.nc
# 2016-10-28 15:00:09 From http://stream.ecmwf.int/data/atls02/data/data01/scratch/_grib2netcdf-atls02-95e2cf679cd58ee9b4db4dd119a05a8d-oW2YWD.nc
# 2016-10-28 15:09:18 Transfer rate 754.567 Kbytes/s
# 2016-10-28 15:09:18 Transfer interrupted, retrying...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0a8e58a0dd95> in <module>()
#      44             'grid'      : "1.00/1.00",
#      45             'target'    : target_loop,
# ---> 46             'format'    : "netcdf"
#      47         })
#      48
#
# /user/skiefer/miniconda3/envs/py27/lib/python2.7/site-packages/ecmwfapi/api.pyc in retrieve(self, req)
#     488         dataset = req.get("dataset")
#     489         c = APIRequest(self.url, "datasets/%s" % (dataset,), self.email, self.key, self.trace, verbose=self.verbose)
# --> 490         c.execute(req, target)
#     491
#     492 ###############################################################################
#
# /user/skiefer/miniconda3/envs/py27/lib/python2.7/site-packages/ecmwfapi/api.pyc in execute(self, request, target)
#     452                     tries += 1
#     453                     self.log("Transfer interrupted, retrying...")
# --> 454                     time.sleep(60)
#     455                 else:
#     456                     break
#
# KeyboardInterrupt:
